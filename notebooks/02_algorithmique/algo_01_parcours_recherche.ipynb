# %% [markdown]
# # 🧠 NSI – Algo 01
# ## Parcours & recherche dans des listes
#
# > Objectif : être à l’aise pour **parcourir** une liste et **chercher** des valeurs dedans.

# %% [markdown]
# ## 1️⃣ Parcourir une liste
#
# On part d’une liste de pseudos :
#
# ```python
# pseudos = ["Stup", "Maxou", "DarkSaucisson", "PizzaLord"]
# ```
#
# Deux façons classiques de parcourir :
# - directement les éléments,
# - ou en utilisant les indices.

# %%
pseudos = ["Stup", "Maxou", "DarkSaucisson", "PizzaLord"]

print("Parcours direct :")
for pseudo in pseudos:
    print("-", pseudo)

print("\nParcours avec indices :")
for i in range(len(pseudos)):
    print(i, pseudos[i])

# %% [markdown]
# ### 📝 Exercice 1 – Parcourir et filtrer
#
# On a une liste de messages :
#
# ```python
# messages = [
#     "yo",
#     "on joue ?",
#     "je suis en retard",
#     "go ranked",
#     "je peux pas là",
# ]
# ```
#
# 1. Afficher tous les messages.
# 2. Afficher uniquement ceux qui contiennent `"go"`.
# 3. Afficher les indices des messages qui contiennent `"je"`.

# %%
messages = [
    "yo",
    "on joue ?",
    "je suis en retard",
    "go ranked",
    "je peux pas là",
]

# TODO 1 : afficher tous les messages

# TODO 2 : afficher uniquement les messages qui contiennent "go"

# TODO 3 : afficher les indices des messages qui contiennent "je"

# %% [markdown]
# ## 2️⃣ Recherche d'une valeur
#
# On veut savoir si une valeur est dans une liste.
#
# Python sait faire :
#
# ```python
# "Maxou" in pseudos
# ```
#
# Mais on recode pour comprendre le principe.

# %%
def contient(liste, valeur):
    """Renvoie True si valeur est dans liste, False sinon.
    À COMPLÉTER
    """
    # TODO : parcours de la liste + test d'égalité
    return False


pseudos = ["Stup", "Maxou", "DarkSaucisson", "PizzaLord"]
print(contient(pseudos, "Maxou"))   # True attendu
print(contient(pseudos, "Random"))  # False attendu

# %% [markdown]
# ### 2.1 Première occurrence
#
# On veut la position de la première occurrence d'une valeur.
#
# Si elle n'est pas trouvée, on renverra `None`.

# %%
def indice_premiere_occurrence(liste, valeur):
    """Renvoie l'indice de la première occurrence de valeur dans liste,
    ou None si valeur absente.
    À COMPLÉTER
    """
    # TODO : parcours avec indices
    return None


pseudos = ["Stup", "Maxou", "DarkSaucisson", "Maxou", "PizzaLord"]
print(indice_premiere_occurrence(pseudos, "Maxou"))   # 1 attendu
print(indice_premiere_occurrence(pseudos, "Random"))  # None attendu

# %% [markdown]
# ## 3️⃣ Maximum & minimum
#
# On va recoder `max` et `min` soi-même pour une liste non vide.

# %%
def maximum(liste):
    """Renvoie le maximum d'une liste non vide.
    À COMPLÉTER
    """
    # TODO : initialiser max_courant, puis parcourir
    return None


def minimum(liste):
    """Renvoie le minimum d'une liste non vide.
    À COMPLÉTER
    """
    # TODO : même principe pour le min
    return None


scores = [1200, 950, 1800, 600, 2000]
print("Max :", maximum(scores))   # 2000 attendu
print("Min :", minimum(scores))   # 600 attendu

# %% [markdown]
# ### 3.1 Indice du max / min
#
# On veut maintenant la position du max et du min.

# %%
def indice_maximum(liste):
    """Renvoie l'indice du maximum d'une liste non vide.
    À COMPLÉTER
    """
    # TODO : garder max_courant + indice_max
    return None


def indice_minimum(liste):
    """Renvoie l'indice du minimum d'une liste non vide.
    À COMPLÉTER
    """
    # TODO : même principe pour le min
    return None


scores = [1200, 950, 1800, 600, 2000]
print("Indice max :", indice_maximum(scores))  # 4 attendu
print("Indice min :", indice_minimum(scores))  # 3 attendu

# %% [markdown]
# ## 4️⃣ Compter, filtrer, transformer
#
# On travaille sur des listes de notes.

# %%
notes = [4, 8, 12, 15, 3, 18]

def nombre_reussites(liste_notes):
    """Renvoie le nombre de notes >= 10.
    À COMPLÉTER
    """
    # TODO : compteur + parcours
    return 0


def ajouter_bonus(liste_notes, bonus):
    """Renvoie une nouvelle liste où chaque note a gagné 'bonus' points.
    (sans modifier la liste d'origine)
    À COMPLÉTER
    """
    # TODO : créer une nouvelle liste, y ajouter les notes modifiées
    return []


def notes_en_dessous_de(liste_notes, seuil):
    """Renvoie une nouvelle liste contenant uniquement les notes < seuil.
    À COMPLÉTER
    """
    # TODO : filtrer dans une nouvelle liste
    return []


print("Nombre de notes >= 10 :", nombre_reussites(notes))
print("Notes avec bonus +2 :", ajouter_bonus(notes, 2))
print("Notes < 10 :", notes_en_dessous_de(notes, 10))
print("Notes originales :", notes)

# %% [markdown]
# ## 5️⃣ Mini-défi – Sélection de joueurs
#
# On manipule une liste de dictionnaires représentant des joueurs.

# %%
joueurs = [
    {"pseudo": "Maxou", "elo": 1200},
    {"pseudo": "Perrine", "elo": 1800},
    {"pseudo": "Jade", "elo": 950},
    {"pseudo": "Stup", "elo": 1500},
]

def meilleur_joueur(joueurs):
    """Renvoie le dictionnaire du joueur au plus grand elo.
    À COMPLÉTER
    """
    # TODO : parcourir la liste, garder le meilleur elo et le joueur associé
    return None


def joueurs_au_dessus_de(joueurs, seuil):
    """Renvoie une nouvelle liste de joueurs dont l'elo >= seuil.
    À COMPLÉTER
    """
    # TODO : filtrer la liste
    return []


def pseudo_du_meilleur(joueurs):
    """Renvoie le pseudo du meilleur joueur (plus grand elo).
    À COMPLÉTER (facultatif)
    """
    # TODO : soit réutiliser meilleur_joueur, soit tout recoder
    return ""


print("Meilleur joueur :", meilleur_joueur(joueurs))
print("Joueurs >= 1400 :", joueurs_au_dessus_de(joueurs, 1400))
print("Pseudo du meilleur :", pseudo_du_meilleur(joueurs))
