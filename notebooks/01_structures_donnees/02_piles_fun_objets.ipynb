# %% [markdown]
# # 🧱 NSI – Notebook 02
# ## Piles (LIFO) – des listes aux objets chaînés
#
# > Objectif : comprendre les piles **simplement avec des listes**, puis voir une version un peu plus sérieuse avec des **objets qui se référencent entre eux** (style maillons / liste chaînée).
#
# On va faire :
# - une pile basique avec `list` Python,
# - puis une pile "from scratch" avec des **objets** qui pointent les uns vers les autres,
# - des exos à chaque étape.

# %% [markdown]
# ## 1️⃣ Rappel : principe d'une pile
#
# Une pile = structure **LIFO** : *Last In, First Out*.
#
# Exemples de piles dans la vraie vie :
# - onglets ouverts dans ton navigateur (si tu fermes toujours le dernier),
# - pile d'assiettes : tu poses au-dessus, tu reprends au-dessus,
# - historique d'actions (Ctrl+Z).
#
# Opérations classiques :
# - `empiler(x)` : ajouter au sommet,
# - `depiler()` : récupérer et retirer le sommet,
# - `est_vide()` : savoir s'il reste quelque chose,
# - éventuellement `sommet()` : lire le sommet sans le retirer.

# %% [markdown]
# ## 2️⃣ Première implémentation : pile avec une liste Python
#
# Convention classique : le **sommet** de la pile est la **fin de la liste**.
#
# On utilise :
# - `append(x)` pour empiler,
# - `pop()` pour dépiler.

# %%
# Exemple simple de pile avec une liste
pile = []  # pile vide

print("Pile au départ :", pile)

# On empile quelques valeurs
pile.append("page_accueil")
pile.append("/profil")
pile.append("/profil/reglages")
print("Après empilements :", pile)

# On dépile la dernière page visitée
derniere_page = pile.pop()
print("Dernière page dépilée :", derniere_page)
print("Pile après dépilement :", pile)
# Out:
# Pile au départ : []
# Après empilements : ['page_accueil', '/profil', '/profil/reglages']
# Dernière page dépilée : /profil/reglages
# Pile après dépilement : ['page_accueil', '/profil']

# %% [markdown]
# ### 📝 Exercice 1 – Type abstrait `PileList`
#
# On veut regrouper les opérations classiques de pile dans des fonctions qui manipulent une liste **sans penser directement à `append` / `pop`**.
#
# À faire :
# - `pile_vide()` → renvoie une nouvelle pile vide (une liste),
# - `est_vide(p)` → renvoie `True` si la pile est vide,
# - `empiler(p, x)` → ajoute `x` au sommet,
# - `depiler(p)` → renvoie l'élément au sommet **et le retire**,
# - `sommet(p)` → renvoie l'élément au sommet sans le retirer.

# %%
def pile_vide():
    """Crée et renvoie une pile vide représentée par une liste.
    À COMPLÉTER
    """
    # TODO
    return []


def est_vide(p):
    """Renvoie True si la pile p est vide, False sinon.
    À COMPLÉTER
    """
    # TODO
    return False


def empiler(p, x):
    """Empile x au sommet de la pile p.
    À COMPLÉTER
    """
    # TODO
    pass


def depiler(p):
    """Dépile et renvoie l'élément au sommet de la pile p.
    On suppose que la pile n'est pas vide.
    À COMPLÉTER
    """
    # TODO
    return None


def sommet(p):
    """Renvoie (sans le retirer) l'élément au sommet de la pile p.
    On suppose que la pile n'est pas vide.
    À COMPLÉTER
    """
    # TODO
    return None


# 🔎 Petit test (à compléter au fur et à mesure)
p = pile_vide()
print("Pile au départ :", p)
print("Est vide ?", est_vide(p))

empiler(p, "action1")
empiler(p, "action2")
empiler(p, "action3")
print("Après empilements :", p)
print("Sommet :", sommet(p))
print("Dépile :", depiler(p))
print("Pile finale :", p)

# %% [markdown]
# ## 3️⃣ Pile "sans liste" : objets chaînés
#
# Là on met un petit niveau au-dessus.
#
# Idée : on va créer **nos propres maillons** qui se pointent les uns vers les autres, comme des wagons de train.
#
# Chaque **maillon** contiendra :
# - une `valeur`,
# - un `suivant` (référence vers le maillon en dessous dans la pile).
#
# La pile, elle, retiendra juste une référence vers le **sommet** (le maillon du dessus).
#
# Visuellement :
#
# ```text
# sommet → [valeur: 42 | suivant] → [valeur: 13 | suivant] → [valeur: 7 | suivant] → None
# ```
#
# On ne s'appuie plus sur les `list` Python pour stocker les éléments, mais sur nos **propres objets**.

# %% [markdown]
# ### 3.1 Classe `Maillon`
#
# Un `Maillon` représente un élément de la pile :
# - une valeur,
# - et un pointeur vers le prochain maillon.

# %%
class Maillon:
    """Un maillon de pile : contient une valeur et une référence vers le maillon suivant."""

    def __init__(self, valeur, suivant=None):
        # TODO : stocker la valeur et le suivant
        self.valeur = valeur  # à adapter si besoin
        self.suivant = suivant  # à adapter si besoin

    def __repr__(self):
        return f"Maillon(valeur={self.valeur!r})"

# %% [markdown]
# ### 3.2 Classe `Pile` basée sur des maillons
#
# La classe `Pile` va gérer :
# - un attribut `sommet` (référence vers le premier maillon),
# - un attribut `taille` (facultatif, mais pratique pour garder le nombre d'éléments).
#
# On veut les méthodes suivantes :
# - `est_vide(self)` → `True` si la pile est vide,
# - `empiler(self, valeur)` → crée un nouveau maillon au sommet,
# - `depiler(self)` → enlève le sommet et renvoie sa valeur,
# - `sommet_valeur(self)` → renvoie la valeur du sommet sans le retirer,
# - `__len__(self)` → permet d'utiliser `len(pile)`,
# - `__repr__(self)` → affichage un peu lisible.

# %%
class Pile:
    """Pile implémentée par maillons chaînés (sans utiliser une liste Python)."""

    def __init__(self):
        # TODO : initialiser le sommet et éventuellement la taille
        self.sommet = None  # sommet de la pile (Maillon ou None)
        self.taille = 0     # nombre d'éléments dans la pile

    def est_vide(self):
        """Renvoie True si la pile est vide."""
        # TODO : renvoyer True si la pile ne contient aucun maillon
        return False

    def empiler(self, valeur):
        """Empile une nouvelle valeur au sommet de la pile."""
        # TODO : créer un nouveau Maillon dont le suivant est l'ancien sommet
        # puis mettre à jour sommet et taille
        pass

    def depiler(self):
        """Dépile et renvoie la valeur au sommet.
        Si la pile est vide, on peut lever une exception ou renvoyer None (à choisir).
        """
        # TODO : récupérer la valeur du sommet, avancer le sommet, mettre à jour la taille
        return None

    def sommet_valeur(self):
        """Renvoie la valeur du sommet sans dépiler.
        À COMPLÉTER
        """
        # TODO : renvoyer la valeur du sommet si non vide
        return None

    def __len__(self):
        """Permet d'utiliser len(pile)."""
        return self.taille

    def __repr__(self):
        """Affichage de la pile du sommet vers le bas (pour debug)."""
        elements = []
        courant = self.sommet
        while courant is not None:
            elements.append(repr(courant.valeur))
            courant = courant.suivant
        return "Pile(" + " -> ".join(elements) + ")"

# %% [markdown]
# ### 📝 Exercice 2 – Compléter la classe `Pile`
#
# 1. Compléter toutes les méthodes marquées `TODO` dans la classe `Pile`.
# 2. Tester avec le code ci-dessous.
# 3. Vérifier que la pile fonctionne comme une pile basée sur des listes, mais **sans utiliser `list` pour stocker les valeurs**.

# %%
# 🔎 Tests
p = Pile()
print("Pile au départ :", p)
print("Est vide ?", p.est_vide())

p.empiler("page_accueil")
p.empiler("/profil")
p.empiler("/profil/reglages")
print("Après empilements :", p)
print("Taille :", len(p))
print("Sommet :", p.sommet_valeur())

print("Dépile :", p.depiler())
print("Après dépilement :", p)
print("Taille :", len(p))

# %% [markdown]
# ## 4️⃣ Utiliser la pile d'objets pour un mini-problème
#
# On va réutiliser la pile pour un petit problème classique : les parenthèses bien formées.
#
# Rappel du principe :
# - Quand on voit `'('` → on empile.
# - Quand on voit `')'` → on dépile.
# - Si on veut dépiler alors que la pile est vide → erreur.
# - À la fin, la pile doit être vide.

# %%
def bien_parenthesee(chaine):
    """Renvoie True si la chaîne de parenthèses est bien parenthésée.
    Utilise la classe Pile définie plus haut.
    À COMPLÉTER
    """
    # TODO : utiliser Pile, empiler pour '(', dépiler pour ')'
    return False


# 🔎 Tests
print(bien_parenthesee("(())()"))  # True attendu
print(bien_parenthesee("(()"))     # False attendu
print(bien_parenthesee(")("))      # False attendu

# %% [markdown]
# ## 5️⃣ Pour aller plus loin
#
# - Ajouter une méthode `vider(self)` qui vide toute la pile.
# - Ajouter une méthode `__iter__(self)` pour pouvoir faire :
#   ```python
#   for valeur in p:
#       print(valeur)
#   ```
# - Modifier `depiler` pour lever une vraie exception Python (`IndexError`) si on essaie de dépiler une pile vide.
#
# ---
#
# 🎯 Si tu arrives à bien compléter ce notebook, tu as :
# - compris le concept de pile,
# - vu une implémentation simple avec `list`,
# - vu une implémentation **plus bas niveau** avec des objets qui se référencent entre eux.
#
# C'est exactement le genre de truc qui aide pour comprendre les **structures de données** plus avancées (listes chaînées, arbres, etc.). 😈
